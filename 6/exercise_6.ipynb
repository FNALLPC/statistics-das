# %%
import ROOT as rt
tfile = rt.TFile.Open('shapes_file.root')
# Out:
# TFile: name=shapes_file.root, title=, option=READ

# %%
# %%bash
# cat myshapes.txt
# Out:
# imax 2
# jmax 2
# kmax 7
# ---------------
# shapes * * shapes_file.root $CHANNEL/$PROCESS  $CHANNEL/$PROCESS_$SYSTEMATIC
# ---------------
# bin ejets mujets
# observation 4734 6448
# ------------------------------
# bin             ejets      ejets   ejets   mujets     mujets    mujets
# process         tprime600  top     ewk     tprime600  top       ewk
# process         0          1       2       0          1         2
# rate            227        4048    760     302        5465.496783      1098.490939
# --------------------------------
# lumi     lnN    1.10        -       -     1.10        -         -
# bgnortop lnN    -          1.114    -     -          1.114      -
# bgnorewk lnN    -           -      1.5    -           -        1.5
# eff_mu   lnN    -           -       -     1.03       1.03      1.03
# eff_e    lnN    1.03       1.03    1.03    -          -         -
# ...

# %%
# %%bash
# combine -v 3 -M AsymptoticLimits  myshapes.txt
# Out:
# >>> including systematics
# >>> method used is AsymptoticLimits
# >>> random number generator seed is 123456
# Creating RooAddPdf pdf_binejets with 3 elements
# Creating RooAddPdf pdf_binmujets with 3 elements
#
# RooWorkspace(w) w contents
#
# variables
# ---------
# (CMS_channel,CMS_th1x,MH,bgnorewk,bgnorewk_In,bgnortop,bgnortop_In,btgsf,btgsf_In,eff_e,eff_e_In,eff_mu,eff_mu_In,jes,jes_In,lumi,lumi_In,r)
#
# p.d.f.s
# -------
# RooSimultaneousOpt::model_b[ indexCat=CMS_channel ejets=pdf_binejets_bonly mujets=pdf_binmujets_bonly extraConstraints=() channelMasks=() ] = 5.77207e-10
#   RooProdPdf::pdf_binejets_bonly[ lumi_Pdf * bgnortop_Pdf * bgnorewk_Pdf * eff_mu_Pdf * eff_e_Pdf * jes_Pdf * btgsf_Pdf * pdf_binejets_bonly_nuis * pdfbins_binejets ] = 0.280894
#     RooAddPdf::pdf_binejets_bonly_nuis[ n_exp_final_binejets_proc_ewk * shapeBkg_ejets_ewk_morph + n_exp_final_binejets_proc_top * shapeBkg_ejets_top_morph ] = 0.280894
# ...
